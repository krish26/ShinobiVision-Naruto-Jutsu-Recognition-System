# %%
import pandas as pd
import cv2

# %%
img = cv2.imread("panda.png")  
print(img.shape)  #numpy array
cv2.imshow('hand sign',img)
cv2.waitKey(0)
# Out:
# (544, 589, 3)
# -1

# %%
img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
cv2.imshow('hand sign',img2)
cv2.waitKey(0)
# Out:
# -1

# %%
pixel = img2[100, 200]
print(pixel) #accessing pixel value
# Out:
# [92 96 83]

# %%
cv2.circle(img2, (200, 100), 50, (0, 0, 255), -1)
# Out:
# array([[[ 31,  31,  31],
#         [ 31,  31,  31],
#         [ 31,  31,  31],
#         ...,
#         [ 31,  31,  31],
#         [ 31,  31,  31],
#         [ 31,  31,  31]],
#
#        [[130, 134, 121],
#         [126, 131, 118],
#         [119, 124, 111],
#         ...,
#         [ 46,  43,  37],
#         [ 46,  43,  37],
#         [ 46,  43,  36]],
#
#        [[130, 134, 121],
#         [126, 131, 118],
#         [119, 124, 111],
#         ...,
#         [ 46,  43,  37],
#         [ 46,  43,  37],
#         [ 46,  43,  36]],
#
#        ...,
#
#        [[134, 130, 123],
#         [ 53,  50,  43],
#         [ 18,  15,   9],
#         ...,
#         [159, 141, 125],
#         [159, 141, 124],
#         [159, 141, 124]],
#
#        [[ 36,  33,  25],
#         [ 19,  16,   9],
#         [ 17,  14,   7],
#         ...,
#         [149, 130, 113],
#         [147, 129, 111],
#         [147, 130, 110]],
#
#        [[  4,   1,   0],
#         [ 18,  15,   8],
#         [ 17,  14,   7],
# ...

# %%
cv2.imshow('hand sign',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()
